# %% [markdown]
# <a id="TableOfContents"></a>
# # TABLE OF CONTENTS:
# <li><a href='#imports'>Imports</a></li>
# <li><a href="#acquire">Acquire</a></li>
# <li><a href='#prepare'>Prepare</a></li>
# <li><a href='#extra'>Extra</a></li>

# %% [markdown]
# <a id="imports"></a>
# # Imports:
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %%
# Vectorization and tables
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Stats
from scipy import stats

# .py files
import wrangle

# %% [markdown]
# <a id="acquire"></a>
# # Acquire:
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %% [markdown]
# Acquire everything from the vanilla zillow database via SQL query and connection
#
# - Vanilla shape:
#     - Rows: 2,985,417
#     - Columns: 68

# %%
zillow = wrangle.acquire()
zillow.shape
# Out:
# /Users/manupfool/codeup-data-science/zillow_project/wrangle.py:70: DtypeWarning: Columns (67) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv('zillow.csv', index_col=0)
# (2985417, 68)

# %% [markdown]
# <a id="prepare"></a>
# # Prepare:
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %% [markdown]
# ### List o' shit to fix:
# - Remove columns
#     - typeconstructiontypeid
#         - ID unnecessary
#     - storytypeid
#         - ID unnecessary
#     - heatingorsystemtypeid
#         - ID unnecessary
#     - buildingclasstypeid
#         - ID unnecessary
#     - architecturalstyletypeid
#         - ID unnecessary
#     - airconditioningtypeid
#         - ID unnecessary
#     - propertylandusetypeid
#         - ID unnecessary
#     - id
#         - ID unnecessary
#     - buildingqualitytypeid
#         - ID unnecessary
#     - decktypeid
#         - ID unnecessary
#     - pooltypeid10
#         - ID unnecessary
#     - pooltypeid7
#         - ID unnecessary
#     - propertycountylandusecode
#         - ID unnecessary
#     - regionidcounty
#         - ID unnecessary
#     - structuretaxvaluedollarcnt
#         - Per instruction
#     - landtaxvaluedollarcnt
#         - Per instruction
#     - taxamount
#         - Per instruction
#     - basementsqft
#         - 99% Nulls
#     - fireplacecnt
#         - 90% Nulls
#     - garagecarcnt
#         - 70% Nulls
#     - garagetotalsqft
#         - 70% Nulls
#     - hashottuborspa
#         - 98% Nulls
#     - poolcnt
#         - 82% Nulls
#     - poolsizesum
#         - 99% Nulls
#     - regionidneighborhood
#         - 61% Nulls
#     - threequarterbathnbr
#         - 89% Nulls
#     - unitcnt
#         - 34% Nulls
#     - numberofstories
#         - 77% Nulls
#     - fireplaceflag
#         - 99% Nulls
#     - taxdelinquencyflag
#         - 98% Nulls
#     - taxdelinquencyyear
#         - 98% Nulls
#     - airconditioningdesc
#         - 73% Nulls
#     - architecturalstyledesc
#         - 99% Nulls
#     - buildingclassdesc
#         - 99% Nulls
#     - heatingorsystemdesc
#         - 37% Nulls
#     - storydesc
#         - 99% Nulls
#     - typeconstructiondesc
#         - 99% Nulls
#     - calculatedbathnbr
#         - Unsure as to what is being described
#     - latitude
#         - Exact location currently unnecessary
#     - longitude
#         - Exact location currently unnecessary
#     - regionidzip
#         - Zipcode currently unnecessary
#     - finishedfloor1squarefeet
#         - 93% Nulls
#     - finishedsquarefeet13
#         - 99% Nulls
#     - finishedsquarefeet15
#         - 94% Nulls
#     - finishedsquarefeet50
#         - 93% Nulls
#     - finishedsquarefeet6
#         - 99% Nulls
#     - propertyzoningdesc
#         - 34% Nulls
#     - yardbuildingsqft17
#         - 97% Nulls
#     - yardbuildingsqft26
#         - 99% Nulls
#     - logerror
#         - 97% Nulls
#     - transactiondate
#         - 97% Nulls
#     - finishedsquarefeet12
#         - Unsure as to what is being described
#     - parcelid
#         - ID unnecessary
#     - rawcensustractandblock
#         - rawvalues do not correctly correlate with a proper census fips code
#     - censustractandblock
#         - Census specific location identifier unnecessary
#     - pooltypeid2
#         - 99% Nulls
# - Fix columns
#     - fips
#         - ID ==> County name
#         - fips ==> county_name
#     - yearbuilt
#         - Fill with mode
#     - bathroomcnt
#         - Fill with mode
#         - bathroomcnt ==> bathrooms
#     - bedroomcnt
#         - Fill with mode
#         - bedroomcnt ==> bedrooms
#     - calculatedfinishedsquarefeet
#         - Fill with mean
#         - calculatedfinishedsquarefeet ==> home_sqft
#     - fullbathcnt
#         - Fill with mode
#         - fullbathcnt ==> full_bathrooms
#     - lotsizesquarefeet
#         - Fill with mean
#         - lotsizesquarefeet ==> lotsize_sqft
#     - regionidcity
#         - ID ==> City name
#         - Fill with mode
#         - regionidcity ==> city_name
#     - roomcnt
#         - Fill with mode
#         - roomcnt ==> rooms
#     - taxvaluedollarcnt
#         - Fill with mean
#         - taxvaluedollarcnt ==> taxvalue
#     - assessmentyear
#         - Fill with mode
#         - assessmentyear ==> yearassessed
#     - propertylandusedesc
#         - Fill with mode
#         - propertylandusedesc ==> property_type

# %%
zillow
# Out:
#          typeconstructiontypeid  storytypeid  heatingorsystemtypeid  \
# 0                           NaN          NaN                    NaN
# 1                           NaN          NaN                    2.0
# 2                           NaN          NaN                    2.0
# 3                           NaN          NaN                    2.0
# 4                           NaN          NaN                    7.0
# ...                         ...          ...                    ...
# 2985412                     NaN          NaN                    NaN
# 2985413                     NaN          NaN                    NaN
# 2985414                     NaN          NaN                    NaN
# 2985415                     NaN          NaN                    NaN
# 2985416                     NaN          NaN                    NaN
#
#          buildingclasstypeid  architecturalstyletypeid  airconditioningtypeid  \
# ...

# %%
# Drop that shit
zillow = zillow.drop(columns=[ 
    'typeconstructiontypeid',
    'storytypeid',
    'heatingorsystemtypeid',
    'buildingclasstypeid',
    'architecturalstyletypeid',
    'airconditioningtypeid',
    'propertylandusetypeid',
    'id',
    'buildingqualitytypeid',
    'decktypeid',
    'pooltypeid10',
    'pooltypeid7',
    'propertycountylandusecode',
    'regionidcounty',
    'structuretaxvaluedollarcnt',
    'landtaxvaluedollarcnt',
    'taxamount',
    'basementsqft',
    'fireplacecnt',
    'garagecarcnt',
    'garagetotalsqft',
    'hashottuborspa',
    'poolcnt',
    'poolsizesum',
    'regionidneighborhood',
    'threequarterbathnbr',
    'unitcnt',
    'numberofstories',
    'fireplaceflag',
    'taxdelinquencyflag',
    'taxdelinquencyyear',
    'airconditioningdesc',
    'architecturalstyledesc',
    'buildingclassdesc',
    'heatingorsystemdesc',
    'storydesc',
    'typeconstructiondesc',
    'calculatedbathnbr',
    #'latitude',
    #'longitude',
    #'regionidzip',
    'finishedfloor1squarefeet',
    'finishedsquarefeet13',
    'finishedsquarefeet15',
    'finishedsquarefeet50',
    'finishedsquarefeet6',
    'propertyzoningdesc',
    'yardbuildingsqft17',
    'yardbuildingsqft26',
    'logerror',
    'transactiondate',
    'finishedsquarefeet12',
    'parcelid',
    'rawcensustractandblock',
    #'censustractandblock',
    'pooltypeid2'])

# %%
zillow.censustractandblock.nunique()
# Out:
# 96755

# %%
zillow[zillow.censustractandblock.fillna(0).astype(str).str.startswith('6111004400')].rawcensustractandblock.to_list()
# Out:
# [61110044.003006,
#  61110044.003002,
#  61110044.001003005,
#  61110044.002013,
#  61110044.003001004,
#  61110044.00300401,
#  61110044.00400501,
#  61110044.004,
#  61110044.00101701,
#  61110044.004031,
#  61110044.001004,
#  61110044.00403199,
#  61110044.00403,
#  61110044.004031,
#  61110044.004008,
#  61110044.00400501,
#  61110044.003002,
#  61110044.00403,
#  61110044.004031,
#  61110044.004031,
#  61110044.003007,
#  61110044.004021,
#  61110044.00400501,
#  61110044.003,
#  61110044.002019,
#  61110044.00401,
#  61110044.00403,
#  61110044.002013,
#  61110036.123045,
#  61110044.002,
#  61110044.00400501,
#  61110044.002001,
#  61110044.001001,
#  61110044.002005,
#  61110044.00400501,
#  61110044.004031,
#  61110044.004017,
#  61110044.002013,
#  61110044.004017,
#  61110044.00403,
#  61110044.003003,
#  61110044.00400501,
#  61110044.004008,
#  61110044.00101701,
#  61110044.004015006,
#  61110044.00400501,
#  61110044.00100601,
#  61110044.003002,
# ...

# %%
zillow[zillow.censustractandblock == 61110044003006]
# Out:
#          bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 0                2.0         4.0                        1848.0  6111.0
# 874519           2.0         3.0                        1320.0  6111.0
# 957240           0.0         0.0                        1896.0  6111.0
# 1534711          0.0         0.0                        2596.0  6111.0
# 1735020          0.0         0.0                        3084.0  6111.0
# 2036521          0.0         0.0                        2792.0  6111.0
# 2205546          0.0         0.0                        2844.0  6111.0
# 2406066          0.0         0.0                        1834.0  6111.0
# 2570502          2.0         2.0                         994.0  6111.0
# 2587845          2.0         2.0                         994.0  6111.0
# 2884989          2.0         2.0                        1075.0  6111.0
#
#          fullbathcnt    latitude    longitude  lotsizesquarefeet  \
# ...

# %%
zillow.censustractandblock.fillna(0).astype(int)
# Out:
# 0          61110044003006
# 1          60371311001009
# 2          60371412023003
# 3          60371060202000
# 4          60372760003014
#                 ...
# 2985412                 0
# 2985413                 0
# 2985414                 0
# 2985415                 0
# 2985416                 0
# Name: censustractandblock, Length: 2985417, dtype: int64

# %%
zillow[zillow.regionidzip == 97109]
# Out:
#          bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet    fips  \
# 0                2.0         4.0                        1848.0  6111.0
# 12               2.0         3.0                        1245.0  6111.0
# 693              2.0         3.0                        1048.0  6111.0
# 1038             2.5         3.0                        1362.0  6111.0
# 1340             2.5         3.0                        1518.0  6111.0
# ...              ...         ...                           ...     ...
# 2982180          1.0         3.0                        1088.0  6111.0
# 2983536          2.0         3.0                        1153.0  6111.0
# 2983538          2.5         3.0                        1215.0  6111.0
# 2984030          2.0         2.0                        1257.0  6111.0
# 2984467          2.0         4.0                        1526.0  6111.0
#
#          fullbathcnt  lotsizesquarefeet  regionidcity  regionidzip  roomcnt  \
# ...

# %%
zillow.regionidzip = zillow.regionidzip.fillna(0).astype(int)
zillow.regionidzip.unique()
# Out:
# array([ 97109,  96415,  96424,  96368,  96026,  96160,  96193,  96505,
#         96956,  97078,  96974,  96993,  97104,  96342,  96337,  96412,
#         96282,  96369,  97319,  96106,  96149,  96229,  96507,  97043,
#         96514,  96998,  96383,  96364,  96361,  97329,  95997,  96240,
#         96244,  96473,  96522,  96996,  97107,  96013,  96373,  97330,
#         96024,  95992,  96083,  96239,  96247,  96173,  96513,  97067,
#         96486,  97106,  97118,  97116,  96349,  96374,  96022,  96523,
#         96959,  97079,  96987,  96190,  97091,  96389,  97328,  97318,
#         96018,  96265,  96110,  96208,  96213,  96117,  96967,  96410,
#         96049,  97008,  97081,  96346,  96095,  96150,  96023,  96113,
#         96210,  96489,  96508,  96962,  96954,  96401,  97016,  96104,
#         96087,  96116,  96480,  97035,  97027,  96393,  96336,  96016,
#         96271,  95983,  96119,  96524,  96186,  96965,  97068,  96983,
# ...

# %%
zillow.regionidcity.fillna(0).astype(int).unique()
# Out:
# array([ 47198,  12447, 118878,  53636,  24384,      0,  21412,  37086,
#         15554,  13150,  38980,   5534,  45398,  10723,  20008,  24812,
#         33837,  52835,  34278,  40227,  46298,  24245,  34636,  12773,
#         54311,  16961, 118225,  33836,  33252,  11626,  27110,  14634,
#         14542,  38032,  25459,   5465,  51239,  30187,  39076,  44116,
#         12292,  19177,  25218,   8384,  34543,  51617,  26964,  32616,
#         45602,  32380,  52650,  27491,  10389,  12520,  51861,  17150,
#         16764,  53655,   9840,  46080,  32753,  18874,  26531,  13693,
#         46098,  33612,  48424,  39308,  53571,  46314, 396550,  47568,
#         33840, 396054,  45457, 396053,  40110, 272578,  24174,  25974,
#         25953,  53027,  32923,  17686,  47547,  54722,  41673,  50749,
#         22827,  24832,   4406,  14111,  34780,  25458,  13091,  45888,
#         54212,  50677,   6395,  10774, 396556,  37015,  30908,  10608,
# ...

# %%
# Fill that shit

# bathroomcnt
# Fill na with mode = 2.0
# Leave as float type (HAS FLOATS)
zillow.bathroomcnt = zillow.bathroomcnt.fillna(2.0)

# bedroomcnt
# Fill na with mode = 3.0 
# Change to int type (NO FLOATS)
zillow.bedroomcnt = zillow.bedroomcnt.fillna(3.0).astype(int)

# calculatedfinishedsquarefeet
# Fill na with mean = 1831.44 
# Leave as float, but filled values are the only floats (ONLY FLOAT)
zillow.calculatedfinishedsquarefeet = zillow.calculatedfinishedsquarefeet.fillna(1831.44)

# fips
# Fill na with mode = 6037 
zillow.fips = zillow.fips.fillna(6037).astype(int)

# fullbathcount
# Fill na with mode = 2.0 
# Change to int type (NO FLOATS)
zillow.fullbathcnt = zillow.fullbathcnt.fillna(2.0).astype(int)

# lotsizesquarefeet
# Fill na with mean = 22604.34 
# Leave as float type (HAS FLOATS)
zillow.lotsizesquarefeet = zillow.lotsizesquarefeet.fillna(22604.34)

# regionidcity
# Fill na with mode = 12447 
# Change to int type (NO FLOATS)
zillow.regionidcity = zillow.regionidcity.fillna(12447).astype(int)

# roomcnt
# Fill na with mode = 0 
# Change to int type (NO FLOATS)
zillow.roomcnt = zillow.roomcnt.fillna(0).astype(int)

# yearbuilt
# Fill na with mode = 1955 
# Change to int type (NO FLOATS)
zillow.yearbuilt = zillow.yearbuilt.fillna(1955).astype(int)

# taxvaluedollarcnt
# Fill na with mean = 443531.42 
# Leave as float, filled values are the only floats (ONLY FLOAT)
zillow.taxvaluedollarcnt = zillow.taxvaluedollarcnt.fillna(443531.42)

# assessmentyear
# Fill na with mode = 2016 
# Change to int type (NO FLOATS)
zillow.assessmentyear = zillow.assessmentyear.fillna(2016).astype(int)

# propertylandusedesc
# Fill na with mode = 'Single Family Residential'
# Leave as object type
zillow.propertylandusedesc = zillow.propertylandusedesc.fillna('Single Family Residential')

# %%
# Fix that shit

# fips 
# 6037 ==> Los Angeles
# 6059 ==> Orange
# 6111 ==> Ventura
# Ensure object type
conditions = [
    zillow.fips == 6037,
    zillow.fips == 6059,
    zillow.fips == 6111
]

choices = [
    'Los Angeles',
    'Orange',
    'Ventura'
]

zillow.fips = np.select(conditions, choices)

# regionidcity

# %%
zillow.regionidcity.value_counts().to_list()
# Out:
# [733053,
#  93462,
#  59797,
#  58620,
#  57017,
#  54304,
#  49127,
#  47764,
#  46280,
#  42115,
#  38794,
#  37823,
#  36093,
#  35621,
#  34451,
#  33810,
#  33338,
#  32553,
#  31381,
#  30356,
#  29237,
#  25782,
#  25037,
#  24817,
#  24591,
#  24168,
#  23034,
#  22562,
#  22467,
#  22268,
#  21986,
#  21560,
#  21332,
#  20858,
#  20627,
#  20243,
#  20148,
#  19990,
#  19129,
#  18993,
#  18426,
#  17829,
#  17744,
#  17461,
#  16590,
#  16531,
#  16362,
#  15990,
#  15833,
#  15677,
#  15190,
#  14976,
#  14769,
#  14556,
#  14529,
#  13788,
#  13750,
#  13613,
#  13539,
#  13506,
#  13500,
#  13314,
#  13085,
#  12992,
#  12395,
#  12189,
#  12143,
#  12041,
#  11925,
#  11744,
#  11701,
#  11683,
#  11561,
#  11446,
#  11374,
#  11269,
#  11260,
#  10401,
#  10396,
#  10226,
#  9815,
#  9799,
#  9759,
#  9167,
#  9075,
#  9075,
#  8984,
#  8964,
#  8431,
#  7986,
#  7986,
#  7772,
#  7686,
#  7673,
#  7660,
#  7545,
#  7513,
#  7465,
#  7214,
#  7005,
#  6987,
#  6655,
# ...

# %%
# Rename that shit

zillow = zillow.rename(columns={
    'bathroomcnt' : 'bathrooms',
    'bedroomcnt' : 'bedrooms',
    'calculatedfinishedsquarefeet' : 'home_sqft',
    'fips' : 'county_name',
    'fullbathcnt' : 'full_bathrooms',
    'lotsizesquarefeet' : 'lotsize_sqft',
    'regionidcity' : 'city_name',
    'roomcnt' : 'rooms',
    'taxvaluedollarcnt' : 'taxvalue',
    'assessmentyear' : 'yearassessed',
    'propertylandusedesc' : 'property_type'
})
# Out:
#          bathrooms  bedrooms  home_sqft  county_name  full_bathrooms  \
# 0              2.0         4    1848.00         6111               2
# 1              2.0         2    1430.00         6037               2
# 2              3.0         2    1347.00         6037               3
# 3              2.0         3    1572.00         6037               2
# 4              2.0         3    1412.00         6037               2
# ...            ...       ...        ...          ...             ...
# 2985412        2.0         3    1831.44         6037               2
# 2985413        2.0         3    1831.44         6037               2
# 2985414        2.0         3    1831.44         6037               2
# 2985415        2.0         3    1831.44         6037               2
# 2985416        2.0         3    1831.44         6037               2
#
#          lotsize_sqft  city_name  rooms  yearbuilt   taxvalue  yearassessed  \
# ...

# %% [markdown]
# <a id="extra"></a>
# # Extra:
# <li><a href='#TableOfContents'>Table of Contents</a></li>

# %%
len(zipcodes)
# Out:
# 159

# %%
test =[47198,  12447, 118878,  53636,  24384,      0,  21412,  37086,
        15554,  13150,  38980,   5534,  45398,  10723,  20008,  24812,
        33837,  52835,  34278,  40227,  46298,  24245,  34636,  12773,
        54311,  16961, 118225,  33836,  33252,  11626,  27110,  14634,
        14542,  38032,  25459,   5465,  51239,  30187,  39076,  44116,
        12292,  19177,  25218,   8384,  34543,  51617,  26964,  32616,
        45602,  32380,  52650,  27491,  10389,  12520,  51861,  17150,
        16764,  53655,   9840,  46080,  32753,  18874,  26531,  13693,
        46098,  33612,  48424,  39308,  53571,  46314, 396550,  47568,
        33840, 396054,  45457, 396053,  40110, 272578,  24174,  25974,
        25953,  53027,  32923,  17686,  47547,  54722,  41673,  50749,
        22827,  24832,   4406,  14111,  34780,  25458,  13091,  45888,
        54212,  50677,   6395,  10774, 396556,  37015,  30908,  10608,
       118694,  47019,  27183,  26483,  52842,  40009,  54970,  15237,
        26965,  54053,  40081,  10734,  39306,  33311,  29189,   6021,
        42150,  10241,  29712,  17882,  30267,  24435,  17597,  44833,
        47762,  47695, 396551, 118914,  13716,  46178, 118895, 113412,
        33727, 118994,  36502,  54352,  21778,  33312,  27103,  54299,
        55753,   3491,  30399,  18098, 118217,  16389, 113576,  42091,
        56780,  37688,  42967, 118875, 116042,  25271,  13232,  16677,
       114828,  14906,  34037,  25621, 118880,  18875,  25468,  53162,
        41484,  13311, 114834,  31134,   6822,  32927,  37882,  19202,
         3980,   6285,  10815,  21395,  24797,  25535,  27512,  40633,
        48211,  36078,  47913]

# %%
df = pd.DataFrame(new_test)
df
# Out:
#           0
# 0         0
# 1      3491
# 2      3980
# 3      4406
# 4      5465
# ..      ...
# 182  396053
# 183  396054
# 184  396550
# 185  396551
# 186  396556
#
# [187 rows x 1 columns]

# %%
new_test
# Out:
# [0,
#  3491,
#  3980,
#  4406,
#  5465,
#  5534,
#  6021,
#  6285,
#  6395,
#  6822,
#  8384,
#  9840,
#  10241,
#  10389,
#  10608,
#  10723,
#  10734,
#  10774,
#  10815,
#  11626,
#  12292,
#  12447,
#  12520,
#  12773,
#  13091,
#  13150,
#  13232,
#  13311,
#  13693,
#  13716,
#  14111,
#  14542,
#  14634,
#  14906,
#  15237,
#  15554,
#  16389,
#  16677,
#  16764,
#  16961,
#  17150,
#  17597,
#  17686,
#  17882,
#  18098,
#  18874,
#  18875,
#  19177,
#  19202,
#  20008,
#  21395,
#  21412,
#  21778,
#  22827,
#  24174,
#  24245,
#  24384,
#  24435,
#  24797,
#  24812,
#  24832,
#  25218,
#  25271,
#  25458,
#  25459,
#  25468,
#  25535,
#  25621,
#  25953,
#  25974,
#  26483,
#  26531,
#  26964,
#  26965,
#  27103,
#  27110,
#  27183,
#  27491,
#  27512,
#  29189,
#  29712,
#  30187,
#  30267,
#  30399,
#  30908,
#  31134,
#  32380,
#  32616,
#  32753,
#  32923,
#  32927,
#  33252,
#  33311,
#  33312,
#  33612,
#  33727,
#  33836,
#  33837,
#  33840,
#  34037,
#  34278,
# ...

# %%
temp1 = [0,
 3491,
 3980,
 4406,
 5465,
 5534,
 6021,
 6285,
 6395,
 6822,
 8384,
 9840,
 10241,
 10389,
 10608,
 10723,
 10734,
 10774,
 10815,
 11626,
 12292,
 12447,
 12520,
 12773,
 13091,
 13150,
 13232,
 13311,
 13693,
 13716,
 14111,
 14542,
 14634,
 14906,
 15237,
 15554,
 16389,
 16677,
 16764,
 16961,
 17150,
 17597,
 17686,
 17882,
 18098,
 18874,
 18875,
 19177,
 19202]

# %%
len(temp1)
# Out:
# 49

# %%
temp1name = ['Los Angeles',
'San Francisco',
'San Jose',
'Sacramento',
'Oakland',
'Berkeley',
'Fresno',
'Long Beach',
'Pasadena',
'Santa Monica',
'Santa Cruz',
'Irvine',
'Santa Barbara',
'San Luis Obispo',
'San Diego',
'Carlsbad',
'Chula Vista',
'El Cajon',
'Escondido',
'Oceanside',
'Palm Springs',
'Riverside',
'Corona',
'Temecula',
'Anaheim',
'Fullerton',
'Huntington Beach',
'Newport Beach',
'Orange',
'Santa Ana',
'Thousand Oaks',
'Simi Valley',
'Ventura',
'Bakersfield',
'Santa Clarita',
'Valencia',
'Pasadena',
'Glendale',
'Burbank',
'Palmdale',
'Lancaster',
'Pomona',
'Redlands',
'San Bernardino',
'Ontario',
'Fontana',
'Rancho Cucamonga',
'Chico',
'Davis']

# %%
len(temp1name)
# Out:
# 49

# %%
temp2 = [20008,
 21395,
 21412,
 21778,
 22827,
 24174,
 24245,
 24384,
 24435,
 24797,
 24812,
 24832,
 25218,
 25271,
 25458,
 25459,
 25468,
 25535,
 25621,
 25953,
 25974,
 26483,
 26531,
 26964,
 26965,
 27103,
 27110,
 27183,
 27491,
 27512,
 29189,
 29712,
 30187,
 30267,
 30399,
 30908,
 31134,
 32380,
 32616,
 32753,
 32923,
 32927,
 33252,
 33311,
 33312,
 33612,
 33727,
 33836,
 33837,
 33840,
 34037,
 34278,
 34543,
 34636,
 34780,
 36078,
 36502,
 37015,
 37086,
 37688,
 37882,
 38032,
 38980,
 39076,
 39306,
 39308,
 40009,
 40081,
 40110,
 40227,
 40633,
 41484,
 41673,
 42091,
 42150,
 42967,
 44116,
 44833,
 45398]

# %%
len(temp2)
# Out:
# 79

# %%
temp2name =

# %%
len(temp2name)
# Out:
# 77
